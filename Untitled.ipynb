# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ppyad\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# # importing required libraries

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.optimizers import SGD
import random

words=[]
documents=[]
classes=[]
ignore_words=['?','!']
df = open('intents.json').read()
intents = json.loads(df)

# %% [markdown]
# # Preprocess the data

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w,intent['tag']))
        
        #add classes list
        if intent['tag']not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# **lemmatization**
# - Lemmatizing is the process of converting a word into its lemma form and then creating a pickle file to store the Python objects which we will use while predicting

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
#removes duplicates from each word,lower the case
words = [
    lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words
]

words = sorted(list(set(words)))

#sort classes
classes = sorted(list(set(classes)))

#documents= combination between patterns and intents
print(len(documents),'documents')

#classes = intents
print(len(classes),'classes',classes)

#words = all words,vocabulary
print(len(words),"unique lemmatized words",words)
# Out:
# 94 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ppyad\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
#pickling the two documents
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %% [markdown]
# # creating training and testing data

# %%
#create training data
training =[]

#create an empty array for output
output_empty = [0]*len(classes)

#training set, bag of words for each sentence
for doc in documents:
    #initialize bag of words
    bag=[]
    
    #list of tokenized words for the pattern
    pattern_words = doc[0]
    
    #lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower())
                    for word in pattern_words]
    # create bag of words array with 1, if words match found in current pattern
    for w in words:
        bag.append(1)if w in pattern_words else bag.append(0)
        
    # output ia '0' for each tag and '1' for current tag(for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag,output_row])

# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)

#creae train and test list, X-patterns, y-patterns
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-18-3c2177d8afb4>:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %% [markdown]
# # Build the model

# %% [markdown]
# - create model 3 layers.
# - first layer 128 neurons,
# - second layer 64 neurons and
# - 3rd output layer contains number of neurons
#
# **equal no of intents to predict output intent with softmax**

# %%
model =Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dense(len(train_y[0]),activation='softmax'))

#compile model.stochastic gradient descent with Nesterov accelerated gradient gives
#good results for this model

sgd = SGD(lr = 0.01,decay = 1e-6,momentum=0.9,nesterov = True)
model.compile(loss = "categorical_crossentropy",optimizer =sgd, metrics = ['accuracy'])


#fitting andsaving the model
hist = model.fit(np.array(train_x),np.array(train_y),epochs=200,
                batch_size=5,verbose= 1)
model.save('chatbot_model.h5',hist)

print("Model created")
# Out:
# C:\Users\ppyad\.conda\envs\chatbotpro\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 19/19 [==============================] - 30s 6ms/step - loss: 2.1667 - accuracy: 0.1569
# Epoch 2/200
# 19/19 [==============================] - 0s 2ms/step - loss: 2.0588 - accuracy: 0.3404
# Epoch 3/200
# 19/19 [==============================] - 0s 3ms/step - loss: 1.8486 - accuracy: 0.6185
# Epoch 4/200
# 19/19 [==============================] - 0s 4ms/step - loss: 1.6400 - accuracy: 0.5909
# Epoch 5/200
# 19/19 [==============================] - 0s 5ms/step - loss: 1.1187 - accuracy: 0.7849
# Epoch 6/200
# 19/19 [==============================] - 0s 5ms/step - loss: 0.9296 - accuracy: 0.7942
# Epoch 7/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.7544 - accuracy: 0.9200
# Epoch 8/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.6163 - accuracy: 0.9328
# Epoch 9/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.8868
# Epoch 10/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.3157 - accuracy: 0.9740
# Epoch 11/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2881 - accuracy: 0.9669
# Epoch 12/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2218 - accuracy: 0.9653
# Epoch 13/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1671 - accuracy: 0.9843
# Epoch 14/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.9848
# Epoch 15/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 1.0000
# Epoch 16/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1154 - accuracy: 0.9790
# Epoch 17/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 1.0000
# Epoch 18/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9942
# Epoch 19/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9843
# Epoch 20/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 21/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 22/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 23/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 24/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 1.0000
# Epoch 25/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 26/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 27/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 28/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 29/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 30/200
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 31/200
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 32/200
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 33/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 34/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 0.9740
# Epoch 35/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9933
# Epoch 36/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 37/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 38/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 39/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 40/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 41/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 42/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 43/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 44/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 45/200
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 46/200
# 19/19 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 47/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 48/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 49/200
# 19/19 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 50/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 51/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 52/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 53/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 54/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 55/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 56/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 57/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 58/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 59/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 60/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 61/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 62/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 63/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 64/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 65/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 66/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 67/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 68/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 69/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 70/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 71/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 72/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 73/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 74/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 75/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 76/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 77/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 78/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 79/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 80/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 81/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 82/200
# 19/19 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 83/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 84/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 85/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 86/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 87/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 88/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 89/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 90/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 91/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 92/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 93/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 94/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 95/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 96/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 97/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9912
# Epoch 98/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 99/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 100/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 101/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 102/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 103/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 104/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 105/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 106/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 107/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 108/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 109/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 110/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 111/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 112/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 113/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 114/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 115/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 116/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 117/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 118/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 119/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 120/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 121/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 122/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 123/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 124/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 125/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 126/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 127/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 128/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 129/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 130/200
# 19/19 [==============================] - 0s 3ms/step - loss: 9.2714e-04 - accuracy: 1.0000
# Epoch 131/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 132/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 133/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 134/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 135/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 136/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 137/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 138/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 139/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 140/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 141/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 142/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 143/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 144/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 145/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 146/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 147/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 148/200
# 19/19 [==============================] - 0s 3ms/step - loss: 9.0276e-04 - accuracy: 1.0000
# Epoch 149/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 150/200
# 19/19 [==============================] - 0s 2ms/step - loss: 6.4589e-04 - accuracy: 1.0000
# Epoch 151/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 152/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 153/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 154/200
# 19/19 [==============================] - 0s 2ms/step - loss: 8.3380e-04 - accuracy: 1.0000
# Epoch 155/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 156/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9978
# Epoch 157/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 158/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 159/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 160/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 161/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 162/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 163/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 164/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 165/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 166/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 167/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 168/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 169/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 170/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 171/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 172/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 173/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 174/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 175/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 176/200
# 19/19 [==============================] - 0s 2ms/step - loss: 6.7433e-04 - accuracy: 1.0000
# Epoch 177/200
# 19/19 [==============================] - 0s 2ms/step - loss: 8.1461e-04 - accuracy: 1.0000
# Epoch 178/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 179/200
# 19/19 [==============================] - 0s 2ms/step - loss: 8.9620e-04 - accuracy: 1.0000
# Epoch 180/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 181/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 182/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 183/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 184/200
# 19/19 [==============================] - 0s 3ms/step - loss: 9.1112e-04 - accuracy: 1.0000
# Epoch 185/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 186/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 187/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 188/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 189/200
# 19/19 [==============================] - 0s 2ms/step - loss: 6.2647e-04 - accuracy: 1.0000
# Epoch 190/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 191/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 192/200
# 19/19 [==============================] - 0s 2ms/step - loss: 7.6530e-04 - accuracy: 1.0000
# Epoch 193/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 194/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 195/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 196/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 197/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 198/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9885
# Epoch 199/200
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 200/200
# 19/19 [==============================] - ETA: 0s - loss: 7.3170e-04 - accuracy: 1.00 - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Model created

# %% [markdown]
# # Predict the Response(GUI)

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model("chatbot_model.h5")
import json
import random
intents = json.loads(open("intents.json").read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints,intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']==tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints =predict_class(text,model)
    res = getResponse(ints,intents)
    return res

# %% [markdown]
# # Creating GUI with tkinter

# %%
import tkinter
from tkinter import*

def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    
    if msg!='':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END,'You:'+msg+'\n\n')
        ChatLog.config(foreground="#442265", font=('Verdana',12))
        
        res = chatbot_response(msg)
        ChatLog.insert(END,'Bot:'+res+'\n\n')
        
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
base=Tk()
base.title('Hello')
base.geometry('400x500')
base.resizable(width=FALSE,height = FALSE)


#create chat window
ChatLog = Text(base,bd=0,bg='white',height='8', width='50',font='Arial',)

ChatLog.config(state=DISABLED)

#bind scrollbar to chat window
scrollbar = Scrollbar(base,command=ChatLog.yview,cursor = 'heart')
ChatLog['yscrollcommand'] = scrollbar.set

#create button to send messages

SendButton = Button(base,font=("Verdana",12,'bold'),text='send',width = '12',height=5,
                   bd=0,bg = "#32de97",
                   activebackground="#3c9d9b",fg='#ffffff',
                    command=send
                   )

#create the box to enter message
EntryBox = Text(base,bd=0,bg="white",width='29',height='5',font='Arial')
#EntryBox.bind("<Return>", send)


#place all components on the screen
scrollbar.place(x=376,y=6,height=386)
ChatLog.place(x=6,y=6,height=386,width=370)
EntryBox.place(x=128,y=401,height=90,width=265)
SendButton.place(x=6,y=401,height=90)

base.mainloop()

# %%
python train_chatbot.py
# Out:
#   File "<ipython-input-34-2177aa7a4d84>", line 1
#     python train_chatbot.py
#            ^
# SyntaxError: invalid syntax

# %%
python chatgui.py
